# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("car_price_dataset.csv")

# %%
df.head()
# Out:
#         Brand   Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 0         Kia     Rio  2020          4.2    Diesel          Manual   289944
# 1   Chevrolet  Malibu  2012          2.0    Hybrid       Automatic     5356
# 2    Mercedes     GLA  2020          4.2    Diesel       Automatic   231440
# 3        Audi      Q5  2023          2.0  Electric          Manual   160971
# 4  Volkswagen    Golf  2003          2.6    Hybrid  Semi-Automatic   286618
#
#    Doors  Owner_Count  Price
# 0      3            5   8501
# 1      2            3  12092
# 2      4            2  11171
# 3      2            1  11780
# 4      3            3   2867

# %%
df.shape
# Out:
# (10000, 10)

# %%
print(f"There are {df.shape[0]} rows and {df.shape[1]} columns in data")
# Out:
# There are 10000 rows and 10 columns in data

# %%
df.columns = df.columns.str.lower()

# %%
df.head()
# Out:
#         brand   model  year  engine_size fuel_type    transmission  mileage  \
# 0         Kia     Rio  2020          4.2    Diesel          Manual   289944
# 1   Chevrolet  Malibu  2012          2.0    Hybrid       Automatic     5356
# 2    Mercedes     GLA  2020          4.2    Diesel       Automatic   231440
# 3        Audi      Q5  2023          2.0  Electric          Manual   160971
# 4  Volkswagen    Golf  2003          2.6    Hybrid  Semi-Automatic   286618
#
#    doors  owner_count  price
# 0      3            5   8501
# 1      2            3  12092
# 2      4            2  11171
# 3      2            1  11780
# 4      3            3   2867

# %%
df.isnull().sum()
# Out:
# brand           0
# model           0
# year            0
# engine_size     0
# fuel_type       0
# transmission    0
# mileage         0
# doors           0
# owner_count     0
# price           0
# dtype: int64

# %%
df.dtypes
# Out:
# brand            object
# model            object
# year              int64
# engine_size     float64
# fuel_type        object
# transmission     object
# mileage           int64
# doors             int64
# owner_count       int64
# price             int64
# dtype: object

# %%
df.describe()
# Out:
#                year   engine_size        mileage         doors   owner_count  \
# count  10000.000000  10000.000000   10000.000000  10000.000000  10000.000000
# mean    2011.543700      3.000560  149239.111800      3.497100      2.991100
# std        6.897699      1.149324   86322.348957      1.110097      1.422682
# min     2000.000000      1.000000      25.000000      2.000000      1.000000
# 25%     2006.000000      2.000000   74649.250000      3.000000      2.000000
# 50%     2012.000000      3.000000  149587.000000      3.000000      3.000000
# 75%     2017.000000      4.000000  223577.500000      4.000000      4.000000
# max     2023.000000      5.000000  299947.000000      5.000000      5.000000
#
#              price
# count  10000.00000
# mean    8852.96440
# std     3112.59681
# min     2000.00000
# 25%     6646.00000
# 50%     8858.50000
# 75%    11086.50000
# max    18301.00000

# %% [markdown]
# ### Information given in the above describe function
#
# ##### The dataset spans car model from the year 2000 to 2023
# ##### The average mileage of the cars in the given data is 1,49,239 kms
# ##### The engine size varies between 1.0 to 5.0 litres
# ##### The car prices ranges from 2000 (minimum) to 18,301 (maximum) and the average price of each car is around 8,852$
# ##### The majority of the cars have 3 or 4 doors

# %%
print(f"Total no. of duplicate values in our data :{df.duplicated().sum()}")
# Out:
# Total no. of duplicate values in our data :0

# %%
brand_counts = df["brand"].value_counts().sort_values(ascending=True)
brand_counts
# Out:
# brand
# Mercedes       942
# Toyota         970
# Kia            976
# Hyundai        995
# BMW            999
# Chevrolet     1003
# Honda         1009
# Volkswagen    1020
# Audi          1038
# Ford          1048
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,4))
sns.countplot(x=df["brand"],order=brand_counts.index,palette="viridis");
# Out:
# C:\Users\jenil\AppData\Local\Temp\ipykernel_8384\1583588656.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["brand"],order=brand_counts.index,palette="viridis");

# %%
df.head()
# Out:
#         brand   model  year  engine_size fuel_type    transmission  mileage  \
# 0         Kia     Rio  2020          4.2    Diesel          Manual   289944
# 1   Chevrolet  Malibu  2012          2.0    Hybrid       Automatic     5356
# 2    Mercedes     GLA  2020          4.2    Diesel       Automatic   231440
# 3        Audi      Q5  2023          2.0  Electric          Manual   160971
# 4  Volkswagen    Golf  2003          2.6    Hybrid  Semi-Automatic   286618
#
#    doors  owner_count  price
# 0      3            5   8501
# 1      2            3  12092
# 2      4            2  11171
# 3      2            1  11780
# 4      3            3   2867

# %%
df[['brand','model']].value_counts()
# Out:
# brand       model
# Honda       Accord      365
# Ford        Fiesta      363
# Chevrolet   Impala      355
# BMW         5 Series    353
# Volkswagen  Tiguan      352
# Ford        Focus       351
# Audi        Q5          350
#             A4          350
# Hyundai     Elantra     347
# Volkswagen  Golf        339
# Audi        A3          338
# Honda       Civic       336
# Kia         Optima      336
# BMW         3 Series    335
# Ford        Explorer    334
# Chevrolet   Malibu      333
# Hyundai     Tucson      329
# Volkswagen  Passat      329
# Kia         Rio         327
# Toyota      Corolla     325
#             RAV4        324
#             Camry       321
# Mercedes    E-Class     321
# Hyundai     Sonata      319
# Chevrolet   Equinox     315
# Mercedes    GLA         315
# Kia         Sportage    313
# BMW         X5          311
# Honda       CR-V        308
# Mercedes    C-Class     306
# Name: count, dtype: int64

# %%
plt.figure(figsize=(23,6))
sns.countplot(x=df['model'],hue=df['brand'])
plt.legend(loc='upper right')
plt.title("Value counts for car models and brands",fontdict={"fontsize":18});

# %%
df.columns
# Out:
# Index(['brand', 'model', 'year', 'engine_size', 'fuel_type', 'transmission',
#        'mileage', 'doors', 'owner_count', 'price'],
#       dtype='object')

# %%
df['mileage']
# Out:
# 0       289944
# 1         5356
# 2       231440
# 3       160971
# 4       286618
#          ...
# 9995      5794
# 9996    168000
# 9997     86664
# 9998    225772
# 9999    157882
# Name: mileage, Length: 10000, dtype: int64

# %%
fig,axis = plt.subplots(nrows=1,ncols=3,figsize=(20,4))
axis = axis.flatten()
for i,var in enumerate(df[['mileage','price','transmission']]):
    sns.histplot(df[var],ax=axis[i],kde=True)
    axis[i].set_xlabel(var)
fig.tight_layout()  
plt.show()

# %%
fig,axis = plt.subplots(nrows=1,ncols=2,figsize=(20,4))
axis = axis.flatten()
for i,var in enumerate(df[['mileage','price']]):
    sns.boxplot(df[var],ax=axis[i],orient='h')
    axis[i].set_xlabel(var)
fig.tight_layout()  
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df[['year','mileage','engine_size','price','doors','owner_count']].corr(),annot=True,cmap='viridis',linecolor='black',lw=2);

# %%
cat_cols = df.select_dtypes(include='object').columns.tolist()
df.head()
# Out:
#         brand   model  year  engine_size fuel_type    transmission  mileage  \
# 0         Kia     Rio  2020          4.2    Diesel          Manual   289944
# 1   Chevrolet  Malibu  2012          2.0    Hybrid       Automatic     5356
# 2    Mercedes     GLA  2020          4.2    Diesel       Automatic   231440
# 3        Audi      Q5  2023          2.0  Electric          Manual   160971
# 4  Volkswagen    Golf  2003          2.6    Hybrid  Semi-Automatic   286618
#
#    doors  owner_count  price
# 0      3            5   8501
# 1      2            3  12092
# 2      4            2  11171
# 3      2            1  11780
# 4      3            3   2867

# %%
X = df.drop(columns=['price','owner_count','doors'])
y = df['price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
print(f"Shape of training data: {X_train.shape}")
print(f"Shape of testing data: {X_test.shape}")
# Out:
# Shape of training data: (8000, 7)
# Shape of testing data: (2000, 7)

# %%
X_train.head()
# Out:
#            brand    model  year  engine_size fuel_type    transmission  \
# 8856    Mercedes  E-Class  2010          3.0  Electric  Semi-Automatic
# 1545  Volkswagen   Tiguan  2002          4.7  Electric          Manual
# 8136   Chevrolet   Impala  2023          1.7    Petrol       Automatic
# 7768       Honda    Civic  2010          1.3    Petrol       Automatic
# 7782         Kia   Optima  2001          3.8    Hybrid       Automatic
#
#       mileage
# 8856   145664
# 1545    92327
# 8136     1631
# 7768     1130
# 7782   149271

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder,StandardScaler

preprocessor = ColumnTransformer(
    transformers=[
        ('ohe', OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'), [0,1,4,5])     
    ],
    remainder='passthrough'
)

lr = LinearRegression()

pipe = Pipeline([
    ('step1',preprocessor),
    ('step2',lr)
])

pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   [0, 1, 4, 5])])),
#                 ('step2', LinearRegression())])

# %%
y_pred = pipe.predict(X_test)
y_pred_train = pipe.predict(X_train)
r2 = r2_score(y_test,y_pred)
print(f"Testing R2 Score: {round(r2*100,2)}%")
r2_train = r2_score(y_train,y_pred_train)
print(f"Training R2 Score: {round(r2_train*100,2)}%")
# Out:
# Testing R2 Score: 99.96%
# Training R2 Score: 99.91%

# %%
sns.regplot(x=y_test,y=y_pred,line_kws={'color':'red'});

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error

cross_val = cross_val_score(pipe,X_train,y_train,cv=10,scoring='r2')

# %%
cross_val
# Out:
# array([0.99981139, 0.99917177, 0.99923896, 0.99926806, 0.99851149,
#        0.99977957, 0.99818701, 0.99956278, 0.9987652 , 0.99908814])

# %%
mae = mean_absolute_error(y_test,y_pred)

# %%
mae
# Out:
# 20.519762174621572

# %%
import pickle

pickle.dump(pipe,open('pipe.pkl','wb'))
pickle.dump(df,open('cars2.pkl','wb'))

# %%
df.head()
# Out:
#         brand   model  year  engine_size fuel_type    transmission  mileage  \
# 0         Kia     Rio  2020          4.2    Diesel          Manual   289944
# 1   Chevrolet  Malibu  2012          2.0    Hybrid       Automatic     5356
# 2    Mercedes     GLA  2020          4.2    Diesel       Automatic   231440
# 3        Audi      Q5  2023          2.0  Electric          Manual   160971
# 4  Volkswagen    Golf  2003          2.6    Hybrid  Semi-Automatic   286618
#
#    doors  owner_count  price
# 0      3            5   8501
# 1      2            3  12092
# 2      4            2  11171
# 3      2            1  11780
# 4      3            3   2867

# %%
df['year'].dtype
# Out:
# dtype('int64')
